# %%
! pip install -qU llama-index-llms-gemini llama-index llama-index-embeddings-gemini

# %%
# !pip install --upgrade google-auth google-auth-oauthlib google-auth-httplib2
# Out:
# Requirement already satisfied: google-auth in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (2.39.0)
# Requirement already satisfied: google-auth-oauthlib in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (1.2.1)
# Requirement already satisfied: google-auth-httplib2 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (0.2.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from google-auth) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from google-auth) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from google-auth) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: httplib2>=0.19.0 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from google-auth-httplib2) (0.22.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from httplib2>=0.19.0->google-auth-httplib2) (3.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2024.8.30)

# %%
# !pip install google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (2.167.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from google-api-python-client) (2.39.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from google-api-python-client) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (5.29.4)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.26.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2024.8.30)

# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (2.25.1)
# Requirement already satisfied: redis>=3.5.3 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from spotipy) (5.2.1)
# Requirement already satisfied: requests>=2.25.0 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from spotipy) (1.26.7)
# Requirement already satisfied: async-timeout>=4.0.3 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from redis>=3.5.3->spotipy) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/akgmac/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (2024.8.30)

# %%
# main.py

from config import GOOGLE_API_KEY, SPOTIFY_CLIENT_ID, SPOTIFY_CLIENT_SECRET, YOUTUBE_API_KEY

# Use the keys as needed
# print(GOOGLE_API_KEY)
# print(SPOTIFY_CLIENT_ID)
# print(SPOTIFY_CLIENT_SECRET)
# print(YOUTUBE_API_KEY)

# %%
from llama_index.llms.gemini import Gemini
llm = Gemini(
    model="models/gemini-1.5-flash",
    api_key=GOOGLE_API_KEY,
)
# Out:
# /var/folders/bm/yljg4k0s08z8hsmjl5t6xygc0000gn/T/ipykernel_28891/630249087.py:2: DeprecationWarning: Call to deprecated class Gemini. (Should use `llama-index-llms-google-genai` instead, using Google's latest unified SDK. See: https://docs.llamaindex.ai/en/stable/examples/llm/google_genai/)
#   llm = Gemini(

# %%
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
import datetime

# Step 1: Define the required scope
SCOPES = ['https://www.googleapis.com/auth/calendar']

# Step 2: Launch the OAuth flow
flow = InstalledAppFlow.from_client_secrets_file('credentials.json', SCOPES)
creds = flow.run_local_server(port=0, open_browser=False)

# Step 3: Build the Calendar API service
service = build('calendar', 'v3', credentials=creds)
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=517564385588-7i13udi12v6mnutpb720b5q9778ascbh.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A51572%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcalendar&state=PAW1mnJA4sengZKcBLlWaJDFslBelc&access_type=offline

# %%
# Input section
topic = input("🎥 Enter the topic you want to explore (e.g., 'learn chess tactics'): ")
preferred_duration_minutes = int(input("⏱️ What is your preferred event duration (in minutes, e.g., 15): "))
reminders_on = input("Would you like a reminder 15 minutes before each event starts?")

# Preview the inputs
print("\n✅ You entered:")
print(f"Topic: {topic}")
print(f"Preferred Duration: {preferred_duration_minutes} minutes")
print(f"Reminders On(yes/no): {reminders_on}")
# Out:
# ✅ You entered:
# Topic: Learn Chess
# Preferred Duration: 15 minutes
# Reminders On(yes/no): yes

# %%
# Youtube API connection to pull the relevant output for user request.

from googleapiclient.discovery import build
from datetime import datetime
import os

# Determine YouTube duration category
if preferred_duration_minutes < 4:
    duration_category = 'short'
elif preferred_duration_minutes <= 20:
    duration_category = 'medium'
else:
    duration_category = 'long'

# Initialize YouTube API
YOUTUBE_API_KEY = YOUTUBE_API_KEY
youtube = build('youtube', 'v3', developerKey=YOUTUBE_API_KEY)

# Search videos
youtube_list = youtube.search().list(
    q=topic,
    part='snippet',
    type='video',
    maxResults=10,
    videoDuration=duration_category,
    order='relevance'
).execute()

# %%
import os
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy

# Set these from your Spotify Developer Dashboard
os.environ['SPOTIPY_CLIENT_ID'] = SPOTIFY_CLIENT_ID
os.environ['SPOTIPY_CLIENT_SECRET'] = SPOTIFY_CLIENT_SECRET
# print(os.environ['SPOTIPY_CLIENT_SECRET'])
# Auth and client
auth_manager = SpotifyClientCredentials()
sp = spotipy.Spotify(auth_manager=auth_manager)

# Search for podcast episodes based on topic
results = sp.search(q=topic, type='episode', limit=10)

# Convert preferred minutes to seconds
max_duration_sec = preferred_duration_minutes * 60

# Filter relevant episodes
spotify_list = [
    ep for ep in results['episodes']['items']
    if ep['duration_ms'] <= max_duration_sec * 1000
]

# %%
# Prompt Gemini to create a nice list for the resulting spotify and youtube results
summarized_list_prompt = f"""spotify_list = {spotify_list}
youtube_list = {youtube_list}
For the above spotify and youtube lists give a formatted version of results that only lists the title and duration for each.
"""

summarized_list = llm.complete(summarized_list_prompt).text.strip()

print(f"🔍 These were the results found: \n{summarized_list}")
# Out:
# 🔍 These were the results found:
# **Spotify Podcasts:**
#
# * **My favorite Chess Advice - Talk To Your Pieces:** 11 minutes, 3 seconds
# * **The Mindset you need for chess success:** 12 minutes, 7 seconds
#
#
# **YouTube Videos:**
#
# * **Basic Chess Openings Explained:**  (Duration not provided)
# * **Learn How to Play Chess for Beginners in Less Than 8 Minutes:** (Duration not provided)
# * **How to Play Chess: Chess Rules for Beginners | ChessKid:** (Duration not provided)
# * **10 Chess Tips Every Beginner Should Know:** (Duration not provided)
# * **Magnus shows how to calculate squares in chess!:** (Duration not provided)
# * **Learn to Play Chess Today in Less Than 10 Minutes:** (Duration not provided)
# * **Every Chess Tip Explained In 10 Minutes:** (Duration not provided)
# * **How I Went From 0 to 1700 Chess Elo in One Year:** (Duration not provided)
# * **LIVE PUZZLE SOLVING || WATCH AND LEARN || #chess:** (Duration not provided)
# * **5 MUST-KNOW Chess Tips For Every Beginner:** (Duration not provided)
#
#
# **Note:** YouTube video durations are not included in the provided data.  The Spotify durations were calculated from the `duration_ms` field.

# %%
def list_events(start_datetime, end_datetime):
    events_result = service.events().list(
        calendarId='primary',
        timeMin=start_datetime.isoformat() + 'Z',
        timeMax=end_datetime.isoformat() + 'Z',
        singleEvents=True,
        orderBy='startTime'
    ).execute()

    events = events_result.get('items', [])
    return events

def get_user_timezone():
    tz_setting = service.settings().get(setting='timezone').execute()
    return tz_setting['value']

def insert_event(event):
  event = service.events().insert(calendarId='primary', body=event).execute()
  return event

# %%
import datetime
userEvents = list_events(datetime.datetime.utcnow(), datetime.datetime.utcnow() + datetime.timedelta(days=20))

# %%
import re
import json

def extract_json_from_text(text):
    """
    Extracts the first JSON array found in the given text.

    Parameters:
        text (str): The text containing the JSON.

    Returns:
        list or None: Parsed JSON object (list of dicts) if found, otherwise None.
    """
    try:
        json_match = re.search(r'```json\s*(\[\s*{.*?}\s*\])\s*```', text, re.DOTALL)
        if json_match:
            json_str = json_match.group(1)
            return json.loads(json_str)
        else:
            print("No JSON found in the text.")
            return None
    except json.JSONDecodeError as e:
        print(f"JSON decoding error: {e}")
        return None

# %%
scheduling_prompt = f"""
This is the user's current schedule: {userEvents}

These are the spotify results: {spotify_list}

These are the youtube results: {youtube_list}

The user's timezone is {get_user_timezone}

The user's reminder preference is {reminders_on}

The user's calendar id is 'primary'.

Create an json array of scheduled events based on the user’s schedule and the Spotify and Youtube results. 
There should only be either one video or one podcast per event.  There should be a max of 2 events per day, one in the morning, one at night.

Give the result in a json format like this:

[
  {{
    'summary': 'Topic: Video or Podcast Title',
    'description': '
    Spotify/Youtube URL: Url here
    Description: Short video or podcast description here if available
    ',
    'start': {{
      'dateTime': '2015-05-28T09:00:00-07:00',
      'timeZone': 'America/Los_Angeles',
    }},
    'end': {{
      'dateTime': '2015-05-28T17:00:00-07:00',
      'timeZone': 'America/Los_Angeles',
    }},
    'reminders': {{
      'useDefault': False,
      'overrides': [
        {{'method': 'popup', 'minutes': 15}},
      ],
    }},
  }}
]

Create a list of events that will be scheduled into Google Calendar based on only the Spotify and Youtube results.  
If it's a Spotify url the description should start with Spotify URL: and if it's a Youtube url it should start with Youtube URL:.
Try to include as many of the Spotify and Youtube results as possible.
Do not include any of the users own events in the resulting json array.
"""

scheduling_list = extract_json_from_text(llm.complete(scheduling_prompt).text.strip())

print(f"Scheduling List: {scheduling_list}")
confirmation_prompt = f"""
Summaries these events that will be scheduled into Google Calendar into a readable format for confirmation by the user.

{scheduling_list}
"""

confirmation = llm.complete(confirmation_prompt).text.strip()
print(f"Scheduling List: {confirmation}")

confirmation_input = input(f"These are the events that will be scheduled, confirm submission?  (y/n)")

if confirmation_input == "y":
  for entry in scheduling_list:
    insert_event(entry)
else:
  print("Then guess you have to start the program over because I am too lazy to return the function or put this in a loop.  Goodbye.")
# Out:
# Scheduling List: [{'summary': 'Topic: My favorite Chess Advice - Talk To Your Pieces', 'description': 'Spotify URL: https://open.spotify.com/episode/6s8Y0eRZ3DpGWEZsCIXS1I\nDescription: Thanks for listening. If you enjoy this podcast, you will certainly enjoy my other content as well. Check it out with the links below: Join my Free Newsletter: https://nextlevelchess.blog Get my free Ebook, The Art of Chess Training: https://nextlevelchess.blog/free-ebook Beginner Chess course (up to 1200 Chess.com / 1400 Lichess): https://courses.nextlevelchess.blog/courses/beginner-chess-mastery How to train chess course (up to 2200 Chess.com): https://courses.nextlevelchess.blog/courses/simplified-chess-improvement-system', 'start': {'dateTime': '2025-04-20T09:00:00-07:00', 'timeZone': 'America/Los_Angeles'}, 'end': {'dateTime': '2025-04-20T10:00:00-07:00', 'timeZone': 'America/Los_Angeles'}, 'reminders': {'useDefault': False, 'overrides': [{'method': 'popup', 'minutes': 15}]}}, {'summary': 'Topic: The Mindset you need for chess success', 'description': 'Spotify URL: https://open.spotify.com/episode/5kvBaQLR95IcDpp9lqze4o\nDescription: Thanks for listening. If you enjoyed this episode, consider leaving a 5-star rating. It really helps. Join my Free Newsletter: https://nextlevelchess.blog Get my free Ebook, The Art of Chess Training: https://nextlevelchess.blog/free-ebook Beginner Chess course (up to 1200 Chess.com / 1400 Lichess): https://courses.nextlevelchess.blog/courses/beginner-chess-mastery How to train chess course (up to 2200 Chess.com): https://courses.nextlevelchess.blog/courses/simplified-chess-improvement-system', 'start': {'dateTime': '2025-04-20T19:00:00-07:00', 'timeZone': 'America/Los_Angeles'}, 'end': {'dateTime': '2025-04-20T20:00:00-07:00', 'timeZone': 'America/Los_Angeles'}, 'reminders': {'useDefault': False, 'overrides': [{'method': 'popup', 'minutes': 15}]}}, {'summary': 'Topic: Basic Chess Openings Explained', 'description': 'Youtube URL: https://www.youtube.com/watch?v=8IlJ3v8I4Z8\nDescription: Get My Chess Courses: https://www.chessly.com/ ➡️ Get my best-selling chess book: https://geni.us/gothamchess ➡️ My book ...', 'start': {'dateTime': '2025-04-21T09:00:00-07:00', 'timeZone': 'America/Los_Angeles'}, 'end': {'dateTime': '2025-04-21T10:00:00-07:00', 'timeZone': 'America/Los_Angeles'}, 'reminders': {'useDefault': False, 'overrides': [{'method': 'popup', 'minutes': 15}]}}, {'summary': 'Topic: Learn How to Play Chess for Beginners in Less Than 8 Minutes', 'description': 'Youtube URL: https://www.youtube.com/watch?v=IU6k-4rKf-g\nDescription: Rules of Chess. Timestamps OR Chapters: 0:00 How to Play Chess? 0:22 Setting Up a Chessboard 0:57 Chess Moves 3:11 ...', 'start': {'dateTime': '2025-04-21T19:00:00-07:00', 'timeZone': 'America/Los_Angeles'}, 'end': {'dateTime': '2025-04-21T20:00:00-07:00', 'timeZone': 'America/Los_Angeles'}, 'reminders': {'useDefault': False, 'overrides': [{'method': 'popup', 'minutes': 15}]}}, {'summary': 'Topic: How to Play Chess: Chess Rules for Beginners | ChessKid', 'description': "Youtube URL: https://www.youtube.com/watch?v=YdnvlntAQH8\nDescription: Play Chess for Free: https://www.chesskid.com/play/computer Want to learn how to play chess? Well, you're in the right place!", 'start': {'dateTime': '2025-04-22T09:00:00-07:00', 'timeZone': 'America/Los_Angeles'}, 'end': {'dateTime': '2025-04-22T10:00:00-07:00', 'timeZone': 'America/Los_Angeles'}, 'reminders': {'useDefault': False, 'overrides': [{'method': 'popup', 'minutes': 15}]}}, {'summary': 'Topic: 10 Chess Tips Every Beginner Should Know', 'description': 'Youtube URL: https://www.youtube.com/watch?v=aavP_NnrXS8\nDescription: We have a lot of new players watching our streams and videos, and we receive hundreds of questions and coaching requests ...', 'start': {'dateTime': '2025-04-22T19:00:00-07:00', 'timeZone': 'America/Los_Angeles'}, 'end': {'dateTime': '2025-04-22T20:00:00-07:00', 'timeZone': 'America/Los_Angeles'}, 'reminders': {'useDef ...
# Then guess you have to start the program over because I am too lazy to return the function or put this in a loop.  Goodbye.
